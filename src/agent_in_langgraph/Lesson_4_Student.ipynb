# %%
from dotenv import load_dotenv

_ = load_dotenv()

# %%
from langgraph.graph import StateGraph, END
from typing import TypedDict, Annotated
import operator
from langchain_core.messages import AnyMessage, SystemMessage, HumanMessage, ToolMessage
from langchain_openai import ChatOpenAI
from langchain_community.tools.tavily_search import TavilySearchResults

# %%
tool = TavilySearchResults(max_results=2)

# %%
class AgentState(TypedDict):
    messages: Annotated[list[AnyMessage], operator.add]

# %%
# pip install langgraph-checkpoint-sqlite
from langgraph.checkpoint.sqlite import SqliteSaver

# memory = SqliteSaver.from_conn_string(":memory:")

# %%
class Agent:
    def __init__(self, model, tools, checkpointer, system=""):
        self.system = system
        graph = StateGraph(AgentState)
        graph.add_node("llm", self.call_openai)
        graph.add_node("action", self.take_action)
        graph.add_conditional_edges("llm", self.exists_action, {True: "action", False: END})
        graph.add_edge("action", "llm")
        graph.set_entry_point("llm")
        # Compile the graph with the checkpointer
        self.graph = graph.compile(checkpointer=checkpointer)
        self.tools = {t.name: t for t in tools}
        self.model = model.bind_tools(tools)

    def call_openai(self, state: AgentState):
        messages = state['messages']
        if self.system:
            messages = [SystemMessage(content=self.system)] + messages
        message = self.model.invoke(messages)
        return {'messages': [message]}

    def exists_action(self, state: AgentState):
        result = state['messages'][-1]
        return len(result.tool_calls) > 0

    def take_action(self, state: AgentState):
        tool_calls = state['messages'][-1].tool_calls
        results = []
        for t in tool_calls:
            print(f"Calling: {t}")
            result = self.tools[t['name']].invoke(t['args'])
            results.append(ToolMessage(tool_call_id=t['id'], name=t['name'], content=str(result)))
        print("Back to the model!")
        return {'messages': results}

# %%
prompt = """You are a smart research assistant. Use the search engine to look up information. \
You are allowed to make multiple calls (either together or in sequence). \
Only look up information when you are sure of what you want. \
If you need to look up some information before asking a follow up question, you are allowed to do that!
"""
model = ChatOpenAI(model="gpt-4o-mini")

with SqliteSaver.from_conn_string("checkpoints.sqlite") as memory:
    abot = Agent(model, [tool], system=prompt, checkpointer=memory)

    messages = [HumanMessage(content="What is the weather in Sydney?")]
    thread = {"configurable": {"thread_id": "1"}}

    for event in abot.graph.stream({"messages": messages}, thread):
        for v in event.values():
            print(v["messages"])


    messages = [HumanMessage(content="How about in Melbourne?")]
    for event in abot.graph.stream({"messages": messages}, thread):
        for v in event.values():
            print(v["messages"])

    messages = [HumanMessage(content="Which one is warmer?")]
    for event in abot.graph.stream({"messages": messages}, thread):
        for v in event.values():
            print(v["messages"])

    snapshot = abot.graph.get_state(thread)
    print(snapshot.values.keys())

    messages = snapshot.values["messages"]

    for i, msg in enumerate(messages):
        print(f"[{i}] {msg.type.upper()} - {msg.content}")

    messages = [HumanMessage(content="Which one is colder?")]
    thread = {"configurable": {"thread_id": "2"}} # change to a different thread_id
    for event in abot.graph.stream({"messages": messages}, thread):
        for v in event.values():
            print(v["messages"])
# Out:
# [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_v1c8uwfPtjo36c73cSCMSKJq', 'function': {'arguments': '{"query":"current weather report Sydney"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 4261, 'total_tokens': 4282, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 4224}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': None, 'id': 'chatcmpl-Bw5DHdJJDt5UoUhyvQDknfROmPZcQ', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run--914a6123-e27a-460e-8232-19c6dcb70810-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather report Sydney'}, 'id': 'call_v1c8uwfPtjo36c73cSCMSKJq', 'type': 'tool_call'}], usage_metadata={'input_tokens': 4261, 'output_tokens': 21, 'total_tokens': 4282, 'input_token_details': {'audio': 0, 'cache_read': 4224}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]
# Calling: {'name': 'tavily_search_results_json', 'args': {'query': 'current weather report Sydney'}, 'id': 'call_v1c8uwfPtjo36c73cSCMSKJq', 'type': 'tool_call'}
# Back to the model!
# [ToolMessage(content="[{'title': 'Sydney weather in July 2025 - Weather25.com', 'url': 'https://www.weather25.com/oceania/australia/new-south-wales/sydney?page=month&month=July', 'content': 'weather25.com\\nSearch\\nweather in Australia\\nRemove from your favorite locations\\nAdd to my locations\\nShare\\nweather in Australia\\n\\n# Sydney weather in July 2025\\n\\nPatchy rain possible\\nClear\\nClear\\nClear\\nLight rain\\nPartly cloudy\\nSunny\\nThundery outbreaks possible\\nCloudy\\nPartly cloudy\\nPartly cloudy\\nPatchy rain possible\\nPatchy rain possible\\nLight rain shower\\n\\n## The average weather in Sydney in July [...] | Sun | Mon | Tue | Wed | Thu | Fri | Sat |\\n| --- | --- | --- | --- | --- | --- | --- |\\n|  |  | 1 Partly cloudy 16° /10° | 2 Light rain shower 18° /12° | 3 Light rain shower 16° /12° | 4 Light rain shower 15° /11° | 5 Light rain shower 16° /12° |\\n| 6 Cloudy 16° /12° | 7 Partly cloudy 16° /11° | 8 Sunny 17° /11° | 9 Sunny 16° /10° | 10 Patchy rain possible 16° /10° | 11 Sunny 17° /11° | 12 Sunny 16° /10° | [...] Partly cloudy\\nLight rain shower\\nLight rain shower\\nLight rain shower\\nLight rain shower\\nCloudy\\nPartly cloudy\\nSunny\\nSunny\\nPatchy rain possible\\nSunny\\nSunny\\nLight rain shower\\nSunny\\nOvercast\\nSunny\\nSunny\\nSunny\\nPartly cloudy\\nPartly cloudy\\nPartly cloudy\\nPatchy rain possible\\nSunny\\nSunny\\nSunny\\nLight rain\\nPartly cloudy\\nSunny\\nThundery outbreaks possible\\nCloudy\\nPartly cloudy\\n\\n## Explore the weather in Sydney in other months\\n\\n## Sydney annual weather', 'score': 0.7785319}, {'title': 'Hourly Weather-Sydney, New South Wales, Australia', 'url': 'https://weather.com/weather/today/l/98ef17e6662508c0af6d8bd04adacecde842fb533434fcd2c046730675fba371', 'content': 'Partly cloudy. Low 46F. Winds W at 5 to 10 mph. Humidity69%.', 'score': 0.62906903}]", name='tavily_search_results_json', tool_call_id='call_v1c8uwfPtjo36c73cSCMSKJq')]
# [AIMessage(content='The current weather in Sydney is partly cloudy, with a low of around 8°C (46°F). The humidity level is approximately 69%, and winds are coming from the west at 5 to 10 mph.\n\nFor the most precise and up-to-date information, refer to a reliable weather service. If you need assistance with anything else, feel free to ask!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 75, 'prompt_tokens': 4848, 'total_tokens': 4923, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 4224}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': None, 'id': 'chatcmpl-Bw5DN1vrQwfJc9bTkzoHyH68kibSU', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--84eb2ca0-58d6-42ec-b8dc-721bf8a3d197-0', usage_metadata={'input_tokens': 4848, 'output_tokens': 75, 'total_tokens': 4923, 'input_token_details': {'audio': 0, 'cache_read': 4224}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]
# [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_8OHSTdD19fGfXpH4AfGYfHZp', 'function': {'arguments': '{"query":"current weather report Melbourne"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 4935, 'total_tokens': 4956, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 4864}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': None, 'id': 'chatcmpl-Bw5DPHnv74z6hJWt74BfoP9A4T89d', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run--91e58779-093f-4450-89ce-6d3258040f6f-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather report Melbourne'}, 'id': 'call_8OHSTdD19fGfXpH4AfGYfHZp', 'type': 'tool_call'}], usage_metadata={'input_tokens': 4935, 'output_tokens': 21, 'total_tokens': 4956, 'input_token_details': {'audio': 0, 'cache_read': 4864}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]
# Calling: {'name': 'tavily_search_results_json', 'args': {'query': 'current weather report Melbourne'}, 'id': 'call_8OHSTdD19fGfXpH4AfGYfHZp', 'type': 'tool_call'}
# Back to the model!
# [ToolMessage(content="[{'title': 'Melbourne Forecast', 'url': 'http://www.bom.gov.au/vic/forecasts/melbourne.shtml', 'content': 'Print Background\\nAustralian Government - Bureau of Meteorology\\n\\nBureau Home > Australia > Victoria > Forecasts > Melbourne Forecast\\n\\n# Melbourne Forecast\\n\\nView the current warnings for Victoria\\n\\nForecast issued at 4:20 pm EST on Tuesday 22 July 2025.\\n\\n## Forecast for the rest of Tuesday\\n\\n### Melbourne area\\n\\nPartly cloudy. Slight chance of a shower, becoming less likely later this evening. Winds northerly 20 to 30 km/h.\\n\\nSun protection not recommended, UV Index predicted to reach 1 [Low] [...] ### Graphical Views\\n\\nThis page was created at 11:12\\non Tuesday 22 July 2025 (UTC)\\n\\n© Copyright Commonwealth of Australia\\n2025, Bureau of Meteorology (ABN 92 637 533 532) |\\nCRICOS Provider 02015K | Disclaimer | Privacy | Accessibility [...] ## Wednesday 23 July\\n\\n### Melbourne area\\n\\nPartly cloudy. High chance of showers, most likely in the afternoon and evening. Possible small hail from the late morning. Winds northwesterly 20 to 30 km/h becoming light in the evening.\\n\\nSun protection not recommended, UV Index predicted to reach 1 [Low]\\n\\n### 7 day Town Forecasts', 'score': 0.9049283}, {'title': 'Melbourne, Victoria, Australia Monthly Weather - AccuWeather', 'url': 'https://www.accuweather.com/en/au/melbourne/26216/july-weather/26216', 'content': 'Get the monthly weather forecast for Melbourne, Victoria, Australia, including daily high/low, historical averages, to help you plan ahead.', 'score': 0.19096565}]", name='tavily_search_results_json', tool_call_id='call_8OHSTdD19fGfXpH4AfGYfHZp')]
# [AIMessage(content='The current weather in Melbourne is partly cloudy with a slight chance of a shower, becoming less likely later in the evening. Winds are coming from the north at 20 to 30 km/h.\n\nIf you need further specifics or assistance, feel free to ask!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 53, 'prompt_tokens': 5370, 'total_tokens': 5423, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 4864}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': None, 'id': 'chatcmpl-Bw5DVz0tIoUdwZlijxhAY0ThKBb3u', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--2ac66503-5f68-4207-9cf4-589502ad3e4f-0', usage_metadata={'input_tokens': 5370, 'output_tokens': 53, 'total_tokens': 5423, 'input_token_details': {'audio': 0, 'cache_read': 4864}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]
# [AIMessage(content='Currently:\n\n- **Sydney**: Partly cloudy with a low of around 8°C (46°F).\n- **Melbourne**: Also partly cloudy, with similar conditions and a slight chance of showers.\n\nBased on this information, Sydney is currently the same as or slightly warmer than Melbourne, as both cities have temperatures around 8°C (46°F). Typically, Sydney tends to be warmer overall than Melbourne, but in this instance, they are comparable. Let me know if you need further information!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 102, 'prompt_tokens': 5435, 'total_tokens': 5537, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 5376}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': None, 'id': 'chatcmpl-Bw5DWTYmNugqSY9A1IU5hVveacqvg', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--8b9ed188-292c-4a80-b519-ba93ffab3f19-0', usage_metadata={'input_tokens': 5435, 'output_tokens': 102, 'total_tokens': 5537, 'input_token_details': {'audio': 0, 'cache_read': 5376}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]
# dict_keys(['messages'])
# [0] HUMAN - What is the weather in Sydney?
# [1] AI -
# [2] TOOL - [{'title': 'Sydney weather in July 2025 - Weather25.com', 'url': 'https://www.weather25.com/oceania/australia/new-south-wales/sydney?page=month&month=July', 'content': 'weather25.com\nSearch\nweather in Australia\nRemove from your favorite locations\nAdd to my locations\nShare\nweather in Australia\n\n# Sydney weather in July 2025\n\nPatchy rain possible\nClear\nClear\nClear\nLight rain\nPartly cloudy\nSunny\nThundery outbreaks possible\nCloudy\nPartly cloudy\nPartly cloudy\nPatchy rain possible\nPatchy rain possible\nLight rain shower\n\n## The average weather in Sydney in July [...] | Sun | Mon | Tue | Wed | Thu | Fri | Sat |\n| --- | --- | --- | --- | --- | --- | --- |\n|  |  | 1 Partly cloudy 16° /10° | 2 Light rain shower 18° /12° | 3 Light rain shower 16° /12° | 4 Light rain shower 15° /11° | 5 Light rain shower 16° /12° |\n| 6 Cloudy 16° /12° | 7 Partly cloudy 16° /11° | 8 Sunny 17° /11° | 9 Sunny 16° /10° | 10 Patchy rain possible 16° /10° | 11 Sunny 17° /11° | 12 Sunny 16° /10° | [...] Partly cloudy\nLight rain shower\nLight rain shower\nLight rain shower\nLight rain shower\nCloudy\nPartly cloudy\nSunny\nSunny\nPatchy rain possible\nSunny\nSunny\nLight rain shower\nSunny\nOvercast\nSunny\nSunny\nSunny\nPartly cloudy\nPartly cloudy\nPartly cloudy\nPatchy rain possible\nSunny\nSunny\nSunny\nLight rain\nPartly cloudy\nSunny\nThundery outbreaks possible\nCloudy\nPartly cloudy\n\n## Explore the weather in Sydney in other months\n\n## Sydney annual weather', 'score': 0.81524754}, {'title': 'Sydney, NSW - Daily Weather Observations - Bureau of Meteorology', 'url': 'http://www.bom.gov.au/climate/dwo/IDCJDW2124.latest.shtml', 'content': 'IDCJDW2124.202507   Prepared at 05:36 UTC on Tuesday 22 July 2025\n\n## Source of data\n\nTemperature, humidity and rainfall observations are from Sydney (Observatory Hill) {station 066214}. Pressure, cloud, evaporation and sunshine observations are from Sydney Airport AMO {station 066037}. Wind observations are from Fort Denison {station 066022}.\n\nSydney Airport is about 10 km to the south of Observatory Hill.\n\nYou should read the important information in these notes.\n\n## Other formats [...] | Statistics for the first 22 days of July 2025 | | | | | | | | | | | | | | | | | | | | | |\n| --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- |\n| Mean | | 9.3 | 18.3 |  | 2.9 | 6.6 |  |  |  | 12.2 | 68 | 3 |  | 18 | 1016.5 | 17.1 | 52 | 3 |  | 17 | 1013.6 |\n| Lowest | | 6.6 | 14.6 | 0 | 1.2 | 0.0 |  |  |  | 9.0 | 39 | 1 | W | 6 | 999.5 | 10.9 | 26 | 0 | NE | 2 | 1001.4 | [...] Print Background\nAustralian Government - Bureau of Meteorology\n\n# Sydney, New South Wales July 2025 Daily Weather Observations\n\nMost observations from Observatory Hill, but some from Fort Denison and Sydney Airport.', 'score': 0.80771893}]
# [3] AI -
# [4] TOOL - [{'title': 'Sydney weather in July 2025 - Weather25.com', 'url': 'https://www.weather25.com/oceania/australia/new-south-wales/sydney?page=month&month=July', 'content': 'weather25.com\nSearch\nweather in Australia\nRemove from your favorite locations\nAdd to my locations\nShare\nweather in Australia\n\n# Sydney weather in July 2025\n\nPatchy rain possible\nClear\nClear\nClear\nLight rain\nPartly cloudy\nSunny\nThundery outbreaks possible\nCloudy\nPartly cloudy\nPartly cloudy\nPatchy rain possible\nPatchy rain possible\nLight rain shower\n\n## The average weather in Sydney in July [...] | Sun | Mon | Tue | Wed | Thu | Fri | Sat |\n| --- | --- | --- | --- | --- | --- | --- |\n|  |  | 1 Partly cloudy 16° /10° | 2 Light rain shower 18° /12° | 3 Light rain shower 16° /12° | 4 Light rain shower 15° /11° | 5 Light rain shower 16° /12° |\n| 6 Cloudy 16° /12° | 7 Partly cloudy 16° /11° | 8 Sunny 17° /11° | 9 Sunny 16° /10° | 10 Patchy rain possible 16° /10° | 11 Sunny 17° /11° | 12 Sunny 16° /10° | [...] Partly cloudy\nLight rain shower\nLight rain shower\nLight rain shower\nLight rain shower\nCloudy\nPartly cloudy\nSunny\nSunny\nPatchy rain possible\nSunny\nSunny\nLight rain shower\nSunny\nOvercast\nSunny\nSunny\nSunny\nPartly cloudy\nPartly cloudy\nPartly cloudy\nPatchy rain possible\nSunny\nSunny\nSunny\nLight rain\nPartly cloudy\nSunny\nThundery outbreaks possible\nCloudy\nPartly cloudy\n\n## Explore the weather in Sydney in other months\n\n## Sydney annual weather', 'score': 0.7923522}, {'title': 'Sydney weather in July 2025 | New South Wales: How hot?', 'url': 'https://www.weather2travel.com/new-south-wales/sydney/july/', 'content': 'weather2travel.com - travel deals for your holiday in the sun\nClick to search\n\n# Sydney weather in July 2025\n\nExpect  daytime maximum temperatures of 17°C in Sydney, New South Wales in July based on long-term weather averages. There are 7 hours of sunshine per day on average with typically 77 mm of rainfall in the month. [...] 17°C maximum daytime temperature in July in Sydney\n7 hours of sunshine per day (64% of daylight hours) in July in Sydney\n8 days with some rainfall in July in Sydney\n8°C minimum night-time temperature in July in Sydney\n10 hours of daylight per day in July in Sydney\nNo heat & humidity in July in Sydney\n77 mm monthly rainfall in July in Sydney\nUV (maximum) index 3 (Moderate) in July in Sydney\n18°C sea temperature in July in Sydney\n\n### More about Sydney [...] Spaceships Rentals\n\nThe July weather guide for New South Wales (Sydney) shows long term weather averages processed from data supplied by CRU (University of East Anglia), the Met Office & the Netherlands Meteorological Institute. Find out more about our data sources.\n\nMetric (°C / mm)  |  Imperial (°F / inches)\n\nBack to top\n\n### More about Australia', 'score': 0.7491794}]
# [5] AI - I wasn't able to find the current weather details for Sydney. However, based on typical weather patterns, Sydney in July usually experiences daytime temperatures around 17°C (63°F) and nighttime temperatures can drop to about 8°C (46°F). Rainfall is common, with around 77 mm expected throughout the month.
#
# For the most accurate and up-to-date weather information, I recommend checking a reliable weather website or app. Would you like assistance with something else?
# [6] HUMAN - How about in Melbourne?
# [7] AI -
# [8] TOOL - [{'title': 'Melbourne weather in July 2025 - Weather25.com', 'url': 'https://www.weather25.com/oceania/australia/victoria/melbourne?page=month&month=July', 'content': 'weather25.com\nSearch\nweather in Australia\nRemove from your favorite locations\nAdd to my locations\nShare\nweather in Australia\n\n# Melbourne weather in July 2025\n\nLight rain\nPatchy light drizzle\nCloudy\nCloudy\nLight rain shower\nLight rain shower\nPatchy rain possible\nLight drizzle\nPatchy rain possible\nPatchy rain possible\nLight rain shower\nSunny\nCloudy\nPatchy rain possible\n\n## The average weather in Melbourne in July [...] | 27 Light rain shower 11° /9° | 28 Patchy rain possible 11° /9° | 29 Light drizzle 9° /8° | 30 Patchy rain possible 11° /9° | 31 Patchy rain possible 14° /9° |  |  | [...] Overcast\nPatchy rain possible\nOvercast\nLight rain\nPartly cloudy\nPatchy rain possible\nPatchy rain possible\nPartly cloudy\nPatchy rain possible\nOvercast\nPatchy rain possible\nLight rain shower\nLight rain shower\nLight rain shower\nLight rain shower\nLight rain shower\nLight rain shower\nOvercast\nOvercast\nCloudy\nLight rain shower\nLight rain\nPatchy light drizzle\nCloudy\nCloudy\nLight rain shower\nLight rain shower\nPatchy rain possible\nLight drizzle\nPatchy rain possible\nPatchy rain possible', 'score': 0.82082915}, {'title': 'Weather Forecast and Conditions for Melbourne, FL', 'url': 'https://weather.com/weather/today/l/Melbourne+FL?canonicalCityId=78ac2189cddf7f4af68d0e20c94404ee', 'content': "Partial cloudiness early, with scattered showers and thunderstorms in the afternoon. High 89F. Winds SE at 10 to 20 mph. Chance of rain 50%.\n\n## Night\n\nA few clouds. Low 78F. Winds SE at 10 to 15 mph.\n\n## Fri 25\n\n## Day\n\nIntervals of clouds and sunshine. A stray shower or thunderstorm is possible. High around 90F. Winds SE at 10 to 20 mph.\n\n## Night\n\nClear skies. Low 77F. Winds SSE at 10 to 15 mph.\n\n## Radar\n\n## Trending Now\n\n## We Love Our Critters\n\n## Summer And Your Skin [...] ## Recent Locations\n\nMenu\n\n## Weather Forecasts\n\n## Radar & Maps\n\n## News & Media\n\n## Products & Account\n\n## Lifestyle\n\n### Specialty Forecasts\n\n# Melbourne, FL\n\n# Hourly Weather-Melbourne, FL\n\n## Now\n\nPartly Cloudy\n\n## 9 am\n\nMostly Cloudy\n\n## 10 am\n\nCloudy\n\n## 11 am\n\nCloudy\n\nChart small gif\n\n## Don't Miss\n\n## Seasonal Hub\n\n# 10 Day Weather-Melbourne, FL\n\n## Today\n\n## Day [...] Partly cloudy skies early with heavy thunderstorms developing this afternoon. High 88F. Winds SW at 10 to 15 mph. Chance of rain 70%.\n\n## Night\n\nMostly cloudy skies. A stray shower or thunderstorm is possible. Low around 75F. Winds SSW at 5 to 10 mph.\n\n## Wed 23\n\n## Day\n\nPartly cloudy with afternoon showers or thunderstorms. High 88F. Winds S at 10 to 15 mph. Chance of rain 40%.\n\n## Night\n\nA few clouds from time to time. Low 77F. Winds S at 5 to 10 mph.\n\n## Thu 24\n\n## Day", 'score': 0.41463867}]
# [9] AI -
# [10] TOOL - [{'title': 'Melbourne weather in July 2025 - Weather25.com', 'url': 'https://www.weather25.com/oceania/australia/victoria/melbourne?page=month&month=July', 'content': '| 27 Light rain shower 11° /9° | 28 Patchy rain possible 11° /9° | 29 Light drizzle 9° /8° | 30 Patchy rain possible 11° /9° | 31 Patchy rain possible 14° /9° |  |  | [...] Overcast\nPatchy rain possible\nOvercast\nLight rain\nPartly cloudy\nPatchy rain possible\nPatchy rain possible\nPartly cloudy\nPatchy rain possible\nOvercast\nPatchy rain possible\nLight rain shower\nLight rain shower\nLight rain shower\nLight rain shower\nLight rain shower\nLight rain shower\nOvercast\nOvercast\nCloudy\nLight rain shower\nLight rain\nPatchy light drizzle\nCloudy\nCloudy\nLight rain shower\nLight rain shower\nPatchy rain possible\nLight drizzle\nPatchy rain possible\nPatchy rain possible [...] weather25.com\nSearch\nweather in Australia\nRemove from your favorite locations\nAdd to my locations\nShare\nweather in Australia\n\n# Melbourne weather in July 2025\n\nLight rain\nPatchy light drizzle\nCloudy\nCloudy\nLight rain shower\nLight rain shower\nPatchy rain possible\nLight drizzle\nPatchy rain possible\nPatchy rain possible\nLight rain shower\nSunny\nCloudy\nPatchy rain possible\n\n## The average weather in Melbourne in July', 'score': 0.82186085}, {'title': 'Weather Forecast and Conditions for Melbourne, FL', 'url': 'https://weather.com/weather/today/l/Melbourne+FL?canonicalCityId=78ac2189cddf7f4af68d0e20c94404ee', 'content': "Partial cloudiness early, with scattered showers and thunderstorms in the afternoon. High 89F. Winds SE at 10 to 20 mph. Chance of rain 50%.\n\n## Night\n\nA few clouds. Low 78F. Winds SE at 10 to 15 mph.\n\n## Fri 25\n\n## Day\n\nIntervals of clouds and sunshine. A stray shower or thunderstorm is possible. High around 90F. Winds SE at 10 to 20 mph.\n\n## Night\n\nClear skies. Low 77F. Winds SSE at 10 to 15 mph.\n\n## Radar\n\n## Trending Now\n\n## We Love Our Critters\n\n## Summer And Your Skin [...] Partly cloudy skies early with heavy thunderstorms developing this afternoon. High 88F. Winds SW at 10 to 15 mph. Chance of rain 70%.\n\n## Night\n\nMostly cloudy skies. A stray shower or thunderstorm is possible. Low around 75F. Winds SSW at 5 to 10 mph.\n\n## Wed 23\n\n## Day\n\nPartly cloudy with afternoon showers or thunderstorms. High 88F. Winds S at 10 to 15 mph. Chance of rain 40%.\n\n## Night\n\nA few clouds from time to time. Low 77F. Winds S at 5 to 10 mph.\n\n## Thu 24\n\n## Day [...] ## Recent Locations\n\nMenu\n\n## Weather Forecasts\n\n## Radar & Maps\n\n## News & Media\n\n## Products & Account\n\n## Lifestyle\n\n### Specialty Forecasts\n\n# Melbourne, FL\n\n# Hourly Weather-Melbourne, FL\n\n## Now\n\nPartly Cloudy\n\n## 9 am\n\nMostly Cloudy\n\n## 10 am\n\nCloudy\n\n## 11 am\n\nCloudy\n\nChart small gif\n\n## Don't Miss\n\n## Seasonal Hub\n\n# 10 Day Weather-Melbourne, FL\n\n## Today\n\n## Day", 'score': 0.42591617}]
# [11] AI - I wasn't able to find the current weather details for Melbourne either. However, based on typical weather patterns in July, Melbourne usually experiences daytime temperatures around 11°C (52°F) and nighttime temperatures around 9°C (48°F). The weather is generally cloudy with frequent light rain or drizzle throughout the month.
#
# For the latest weather updates, it's best to check a reliable weather website or app. Let me know if you need help with anything else!
# [12] HUMAN - Which one is warmer?
# [13] AI - In July, Sydney typically has daytime temperatures around 17°C (63°F) and nighttime temperatures around 8°C (46°F), while Melbourne usually sees daytime temperatures around 11°C (52°F) and nighttime temperatures around 9°C (48°F).
#
# Therefore, Sydney is generally warmer than Melbourne in July. If you have any more questions or need further assistance, feel free to ask!
# [14] HUMAN - Which one is colder?
# [15] AI - In July, Melbourne is generally colder than Sydney.
#
# - **Sydney**: Daytime temperatures around 17°C (63°F) and nighttime temperatures around 8°C (46°F).
# - **Melbourne**: Daytime temperatures around 11°C (52°F) and nighttime temperatures around 9°C (48°F).
#
# So, Melbourne is the colder of the two cities during this month. If you have any other questions or need additional information, just let me know!
# [16] HUMAN - Which one is bigger?
# [17] AI - Sydney is larger than Melbourne in terms of population and metropolitan area.
#
# - **Sydney**: As of recent estimates, the Greater Sydney area has a population of over 5.3 million people, making it the most populous city in Australia. The metropolitan area covers approximately 12,368 square kilometers (4,775 square miles).
#
# - **Melbourne**: Melbourne has a population of about 5 million people, making it the second-most populous city in Australia. Its metropolitan area spans around 9,992 square kilometers (3,858 square miles).
#
# In summary, Sydney is the larger city both in terms of population and geographic area. If you need further details, feel free to ask!
# [18] HUMAN - What is the weather in Sydney?
# [19] AI -
# [20] TOOL - [{'title': 'Sydney weather in July 2025 - Weather25.com', 'url': 'https://www.weather25.com/oceania/australia/new-south-wales/sydney?page=month&month=July', 'content': 'weather25.com\nSearch\nweather in Australia\nRemove from your favorite locations\nAdd to my locations\nShare\nweather in Australia\n\n# Sydney weather in July 2025\n\nPatchy rain possible\nClear\nClear\nClear\nLight rain\nPartly cloudy\nSunny\nThundery outbreaks possible\nCloudy\nPartly cloudy\nPartly cloudy\nPatchy rain possible\nPatchy rain possible\nLight rain shower\n\n## The average weather in Sydney in July [...] | Sun | Mon | Tue | Wed | Thu | Fri | Sat |\n| --- | --- | --- | --- | --- | --- | --- |\n|  |  | 1 Partly cloudy 16° /10° | 2 Light rain shower 18° /12° | 3 Light rain shower 16° /12° | 4 Light rain shower 15° /11° | 5 Light rain shower 16° /12° |\n| 6 Cloudy 16° /12° | 7 Partly cloudy 16° /11° | 8 Sunny 17° /11° | 9 Sunny 16° /10° | 10 Patchy rain possible 16° /10° | 11 Sunny 17° /11° | 12 Sunny 16° /10° | [...] Partly cloudy\nLight rain shower\nLight rain shower\nLight rain shower\nLight rain shower\nCloudy\nPartly cloudy\nSunny\nSunny\nPatchy rain possible\nSunny\nSunny\nLight rain shower\nSunny\nOvercast\nSunny\nSunny\nSunny\nPartly cloudy\nPartly cloudy\nPartly cloudy\nPatchy rain possible\nSunny\nSunny\nSunny\nLight rain\nPartly cloudy\nSunny\nThundery outbreaks possible\nCloudy\nPartly cloudy\n\n## Explore the weather in Sydney in other months\n\n## Sydney annual weather', 'score': 0.7785319}, {'title': 'Hourly Weather-Sydney, New South Wales, Australia', 'url': 'https://weather.com/weather/today/l/98ef17e6662508c0af6d8bd04adacecde842fb533434fcd2c046730675fba371', 'content': 'Partly cloudy. Low 46F. Winds W at 5 to 10 mph. Humidity69%.', 'score': 0.62906903}]
# [21] AI - The current weather in Sydney is partly cloudy, with a low of around 8°C (46°F). The humidity level is approximately 69%, and winds are coming from the west at 5 to 10 mph.
#
# For the most precise and up-to-date information, refer to a reliable weather service. If you need assistance with anything else, feel free to ask!
# [22] HUMAN - How about in Melbourne?
# [23] AI -
# [24] TOOL - [{'title': 'Melbourne Forecast', 'url': 'http://www.bom.gov.au/vic/forecasts/melbourne.shtml', 'content': 'Print Background\nAustralian Government - Bureau of Meteorology\n\nBureau Home > Australia > Victoria > Forecasts > Melbourne Forecast\n\n# Melbourne Forecast\n\nView the current warnings for Victoria\n\nForecast issued at 4:20 pm EST on Tuesday 22 July 2025.\n\n## Forecast for the rest of Tuesday\n\n### Melbourne area\n\nPartly cloudy. Slight chance of a shower, becoming less likely later this evening. Winds northerly 20 to 30 km/h.\n\nSun protection not recommended, UV Index predicted to reach 1 [Low] [...] ### Graphical Views\n\nThis page was created at 11:12\non Tuesday 22 July 2025 (UTC)\n\n© Copyright Commonwealth of Australia\n2025, Bureau of Meteorology (ABN 92 637 533 532) |\nCRICOS Provider 02015K | Disclaimer | Privacy | Accessibility [...] ## Wednesday 23 July\n\n### Melbourne area\n\nPartly cloudy. High chance of showers, most likely in the afternoon and evening. Possible small hail from the late morning. Winds northwesterly 20 to 30 km/h becoming light in the evening.\n\nSun protection not recommended, UV Index predicted to reach 1 [Low]\n\n### 7 day Town Forecasts', 'score': 0.9049283}, {'title': 'Melbourne, Victoria, Australia Monthly Weather - AccuWeather', 'url': 'https://www.accuweather.com/en/au/melbourne/26216/july-weather/26216', 'content': 'Get the monthly weather forecast for Melbourne, Victoria, Australia, including daily high/low, historical averages, to help you plan ahead.', 'score': 0.19096565}]
# [25] AI - The current weather in Melbourne is partly cloudy with a slight chance of a shower, becoming less likely later in the evening. Winds are coming from the north at 20 to 30 km/h.
#
# If you need further specifics or assistance, feel free to ask!
# [26] HUMAN - Which one is warmer?
# [27] AI - Currently:
#
# - **Sydney**: Partly cloudy with a low of around 8°C (46°F).
# - **Melbourne**: Also partly cloudy, with similar conditions and a slight chance of showers.
#
# Based on this information, Sydney is currently the same as or slightly warmer than Melbourne, as both cities have temperatures around 8°C (46°F). Typically, Sydney tends to be warmer overall than Melbourne, but in this instance, they are comparable. Let me know if you need further information!
# [AIMessage(content='I still need more details to answer your question. Can you clarify what specific places, items, or situations you are comparing to determine which one is colder?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 32, 'prompt_tokens': 194, 'total_tokens': 226, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': None, 'id': 'chatcmpl-Bw5DZDh2QaJv6it7bgtZRTZFOo1Gf', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--4a5a2a12-873b-4ae2-90ff-846fccc8a1b1-0', usage_metadata={'input_tokens': 194, 'output_tokens': 32, 'total_tokens': 226, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]

# %%
with SqliteSaver.from_conn_string("checkpoints.sqlite") as memory:
    abot = Agent(model, [tool], system=prompt, checkpointer=memory)

    messages = [HumanMessage(content="Which one is colder?")]
    thread = {"configurable": {"thread_id": "1"}}

    for event in abot.graph.stream({"messages": messages}, thread):
        for v in event.values():
            print(v["messages"])
# Out:
# [AIMessage(content='Currently, both Sydney and Melbourne have similar temperatures of around 8°C (46°F). Therefore, neither city is noticeably colder than the other at this moment; they are quite comparable in temperature.\n\nTypically, however, Melbourne is often colder than Sydney, especially during the winter months. Should you need more details or information, feel free to ask!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 70, 'prompt_tokens': 5549, 'total_tokens': 5619, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 5504}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': None, 'id': 'chatcmpl-Bw5Dby10qD0h3657IaMV9hhqqodXk', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--e0385590-aa96-4011-93be-f6badd5aab12-0', usage_metadata={'input_tokens': 5549, 'output_tokens': 70, 'total_tokens': 5619, 'input_token_details': {'audio': 0, 'cache_read': 5504}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]

# %%
with SqliteSaver.from_conn_string("checkpoints.sqlite") as memory:
    abot = Agent(model, [tool], system=prompt, checkpointer=memory)

    messages = [HumanMessage(content="Which one is bigger?")]
    thread = {"configurable": {"thread_id": "1"}}

    for event in abot.graph.stream({"messages": messages}, thread):
        for v in event.values():
            print(v["messages"])
# Out:
# [AIMessage(content="Sydney is larger than Melbourne in terms of both population and metropolitan area.\n\n- **Population**: \n  - **Sydney** has a population of over 5.3 million people, making it the most populous city in Australia.\n  - **Melbourne** has a population of about 5 million people, making it the second-most populous city in the country.\n\n- **Area**:\n  - **Sydney's metropolitan area** covers approximately 12,368 square kilometers (4,775 square miles).\n  - **Melbourne's metropolitan area** spans about 9,992 square kilometers (3,858 square miles).\n\nIn summary, Sydney is larger than Melbourne both in terms of population and geographic area. If you have further questions or need additional information, feel free to ask!", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 158, 'prompt_tokens': 5631, 'total_tokens': 5789, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 5504}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': None, 'id': 'chatcmpl-Bw5DdMRtwLhADSeFSGIRayXK4d5H2', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--56acbc3d-bc51-4076-a1e0-07d39effeebf-0', usage_metadata={'input_tokens': 5631, 'output_tokens': 158, 'total_tokens': 5789, 'input_token_details': {'audio': 0, 'cache_read': 5504}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]

# %%
import sqlite3

conn = sqlite3.connect("checkpoints.sqlite")
cursor = conn.cursor()

import pandas as pd

def show_query_as_df(cursor, query):
    cursor.execute(query)
    rows = cursor.fetchall()
    columns = [description[0] for description in cursor.description]
    return pd.DataFrame(rows, columns=columns)

# 查看 checkpoints 表结构
df_checkpoints_schema = show_query_as_df(cursor, "PRAGMA table_info(checkpoints);")
display(df_checkpoints_schema)

# 查看 writes 表结构
df_writes_schema = show_query_as_df(cursor, "PRAGMA table_info(writes);")
display(df_writes_schema)

# 查看 checkpoints 表数据
df_checkpoints_data = show_query_as_df(cursor, "SELECT * FROM checkpoints;")
display(df_checkpoints_data)

# 查看 writes 表数据
df_writes_data = show_query_as_df(cursor, "SELECT * FROM writes;")
display(df_writes_data)
# Out:
#    cid                  name  type  notnull dflt_value  pk
# 0    0             thread_id  TEXT        1       None   1
# 1    1         checkpoint_ns  TEXT        1         ''   2
# 2    2         checkpoint_id  TEXT        1       None   3
# 3    3  parent_checkpoint_id  TEXT        0       None   0
# 4    4                  type  TEXT        0       None   0
# 5    5            checkpoint  BLOB        0       None   0
# 6    6              metadata  BLOB        0       None   0
#    cid           name     type  notnull dflt_value  pk
# 0    0      thread_id     TEXT        1       None   1
# 1    1  checkpoint_ns     TEXT        1         ''   2
# 2    2  checkpoint_id     TEXT        1       None   3
# 3    3        task_id     TEXT        1       None   4
# 4    4            idx  INTEGER        1       None   5
# 5    5        channel     TEXT        1       None   0
# 6    6           type     TEXT        0       None   0
# 7    7          value     BLOB        0       None   0
#    thread_id checkpoint_ns                         checkpoint_id  \
# 0          1                1f066ec4-49c7-6046-bfff-aa65c5cbcec3
# 1          1                1f066ec4-49c8-66a8-8000-4b08d16125ef
# 2          1                1f066ec4-6070-60b8-8001-00e909555671
# 3          1                1f066ec4-97be-65c4-8002-8daa640e6861
# 4          1                1f066ec4-a2af-6910-8003-1170cfbe1fe8
# 5          1                1f066ec4-deff-6b18-8004-ef6df0779f6a
# 6          1                1f066ec4-fd4c-638c-8005-cc73c01fda20
# 7          1                1f066ec4-fd55-69a0-8006-d0009df1319f
# 8          1                1f066ec4-fd57-6480-8007-227b38662929
# 9          1                1f066ec5-09cc-6760-8008-07515c154ab5
# 10         1                1f066ec5-3cc4-6992-8009-b85b83aa92b4
# 11         1                1f066ec5-57f9-6488-800a-0f456c16e0ac
# 12         1                1f066ec5-8fc5-6c2c-800b-6395c5880df3
# 13         1                1f066ec5-a2b8-6fe6-800c-b4918d7814ab
# 14         1                1f066ec5-a2c3-666c-800d-c074f571f05c
# 15         1                1f066ec5-a2c5-6a70-800e-5b390d5b2976
# 16         1                1f066ec5-b7d7-6d0a-800f-08c7ac161005
# 17         2                1f066ec5-b7e4-624e-bfff-70a3fe8edeee
# 18         2                1f066ec5-b7e5-6b6c-8000-ef3be16b59fc
# 19         2                1f066ec5-d1e4-628e-8001-89e5f769216d
# 20         1                1f066ec5-d217-6af8-8010-d8f6ab20010a
# 21         1                1f066ec5-d21a-608c-8011-77f72934f83e
# 22         1                1f066ec5-e189-6cc0-8012-7eec39442972
# 23         1                1f066ec5-e1ba-60fa-8013-cc7acbad5ded
# 24         1                1f066ec5-e1bc-6e22-8014-1da7d3d1b498
# 25         1                1f066ec5-fb64-658c-8015-d4f93ce939fb
# 26         1                1f066ecc-9771-6be0-8016-9bff5c6030c6
# 27         1                1f066ecc-9826-65ea-8017-d9eba0120f19
# 28         1                1f066ecc-a34d-68e2-8018-008853db5a9e
# 29         1                1f066ecc-d713-69c4-8019-acefed21b048
# 30         1                1f066ecc-e7a5-6e4a-801a-ee57137b7bfd
# 31         1                1f066ecc-e7b1-6e84-801b-c1b8d5c47352
# 32         1                1f066ecc-e7b4-6d46-801c-460e75eda38a
# 33         1                1f066ecc-f3cd-6dbc-801d-16d70be516fd
# 34         1                1f066ecd-2341-6d6e-801e-1ae39eee4921
# 35         1                1f066ecd-2ef9-6a80-801f-7ad028082567
# 36         1                1f066ecd-2f08-6256-8020-98c20b22a666
# 37         1                1f066ecd-2f0b-62d0-8021-d19842093626
# 38         1                1f066ecd-4861-65a4-8022-ca896f137160
# 39         2                1f066ecd-4871-6ce2-8002-0eb227fdf6b0
# 40         2                1f066ecd-4874-6014-8003-4c7adb383f9a
# 41         2                1f066ecd-59ec-631e-8004-2311f98d8bd7
# 42         1                1f066ecd-5a21-64a6-8023-9f708beb1d3b
# 43         1                1f066ecd-5a24-63b8-8024-7a9777ddb6e0
# 44         1                1f066ecd-698a-6834-8025-6a415256f5bd
# 45         1                1f066ecd-69b4-60e4-8026-780ddfd1e793
# 46         1                1f066ecd-69b6-63b2-8027-09df719c6a4f
# 47         1                1f066ecd-8d39-6fe6-8028-f1ee0d9fce35
#
#                     parent_checkpoint_id     type  \
# 0                                   None  msgpack
# 1   1f066ec4-49c7-6046-bfff-aa65c5cbcec3  msgpack
# 2   1f066ec4-49c8-66a8-8000-4b08d16125ef  msgpack
# 3   1f066ec4-6070-60b8-8001-00e909555671  msgpack
# 4   1f066ec4-97be-65c4-8002-8daa640e6861  msgpack
# 5   1f066ec4-a2af-6910-8003-1170cfbe1fe8  msgpack
# 6   1f066ec4-deff-6b18-8004-ef6df0779f6a  msgpack
# 7   1f066ec4-fd4c-638c-8005-cc73c01fda20  msgpack
# 8   1f066ec4-fd55-69a0-8006-d0009df1319f  msgpack
# 9   1f066ec4-fd57-6480-8007-227b38662929  msgpack
# 10  1f066ec5-09cc-6760-8008-07515c154ab5  msgpack
# 11  1f066ec5-3cc4-6992-8009-b85b83aa92b4  msgpack
# 12  1f066ec5-57f9-6488-800a-0f456c16e0ac  msgpack
# 13  1f066ec5-8fc5-6c2c-800b-6395c5880df3  msgpack
# 14  1f066ec5-a2b8-6fe6-800c-b4918d7814ab  msgpack
# 15  1f066ec5-a2c3-666c-800d-c074f571f05c  msgpack
# 16  1f066ec5-a2c5-6a70-800e-5b390d5b2976  msgpack
# 17                                  None  msgpack
# 18  1f066ec5-b7e4-624e-bfff-70a3fe8edeee  msgpack
# 19  1f066ec5-b7e5-6b6c-8000-ef3be16b59fc  msgpack
# 20  1f066ec5-b7d7-6d0a-800f-08c7ac161005  msgpack
# 21  1f066ec5-d217-6af8-8010-d8f6ab20010a  msgpack
# 22  1f066ec5-d21a-608c-8011-77f72934f83e  msgpack
# 23  1f066ec5-e189-6cc0-8012-7eec39442972  msgpack
# 24  1f066ec5-e1ba-60fa-8013-cc7acbad5ded  msgpack
# 25  1f066ec5-e1bc-6e22-8014-1da7d3d1b498  msgpack
# 26  1f066ec5-fb64-658c-8015-d4f93ce939fb  msgpack
# 27  1f066ecc-9771-6be0-8016-9bff5c6030c6  msgpack
# 28  1f066ecc-9826-65ea-8017-d9eba0120f19  msgpack
# 29  1f066ecc-a34d-68e2-8018-008853db5a9e  msgpack
# 30  1f066ecc-d713-69c4-8019-acefed21b048  msgpack
# 31  1f066ecc-e7a5-6e4a-801a-ee57137b7bfd  msgpack
# 32  1f066ecc-e7b1-6e84-801b-c1b8d5c47352  msgpack
# 33  1f066ecc-e7b4-6d46-801c-460e75eda38a  msgpack
# 34  1f066ecc-f3cd-6dbc-801d-16d70be516fd  msgpack
# 35  1f066ecd-2341-6d6e-801e-1ae39eee4921  msgpack
# 36  1f066ecd-2ef9-6a80-801f-7ad028082567  msgpack
# 37  1f066ecd-2f08-6256-8020-98c20b22a666  msgpack
# 38  1f066ecd-2f0b-62d0-8021-d19842093626  msgpack
# 39  1f066ec5-d1e4-628e-8001-89e5f769216d  msgpack
# 40  1f066ecd-4871-6ce2-8002-0eb227fdf6b0  msgpack
# 41  1f066ecd-4874-6014-8003-4c7adb383f9a  msgpack
# 42  1f066ecd-4861-65a4-8022-ca896f137160  msgpack
# 43  1f066ecd-5a21-64a6-8023-9f708beb1d3b  msgpack
# 44  1f066ecd-5a24-63b8-8024-7a9777ddb6e0  msgpack
# 45  1f066ecd-698a-6834-8025-6a415256f5bd  msgpack
# 46  1f066ecd-69b4-60e4-8026-780ddfd1e793  msgpack
# 47  1f066ecd-69b6-63b2-8027-09df719c6a4f  msgpack
#
#                                            checkpoint  \
# 0   b'\x86\xa1v\x04\xa2ts\xd9 2025-07-22T11:08:59....
# 1   b'\x86\xa1v\x04\xa2ts\xd9 2025-07-22T11:08:59....
# 2   b'\x86\xa1v\x04\xa2ts\xd9 2025-07-22T11:09:02....
# 3   b'\x86\xa1v\x04\xa2ts\xd9 2025-07-22T11:09:07....
# 4   b'\x86\xa1v\x04\xa2ts\xd9 2025-07-22T11:09:09....
# 5   b'\x86\xa1v\x04\xa2ts\xd9 2025-07-22T11:09:15....
# 6   b'\x86\xa1v\x04\xa2ts\xd9 2025-07-22T11:09:18....
# 7   b'\x86\xa1v\x04\xa2ts\xd9 2025-07-22T11:09:18....
# 8   b'\x86\xa1v\x04\xa2ts\xd9 2025-07-22T11:09:18....
# 9   b'\x86\xa1v\x04\xa2ts\xd9 2025-07-22T11:09:19....
# 10  b'\x86\xa1v\x04\xa2ts\xd9 2025-07-22T11:09:25....
# 11  b'\x86\xa1v\x04\xa2ts\xd9 2025-07-22T11:09:28....
# 12  b'\x86\xa1v\x04\xa2ts\xd9 2025-07-22T11:09:33....
# 13  b'\x86\xa1v\x04\xa2ts\xd9 2025-07-22T11:09:35....
# 14  b'\x86\xa1v\x04\xa2ts\xd9 2025-07-22T11:09:35....
# 15  b'\x86\xa1v\x04\xa2ts\xd9 2025-07-22T11:09:35....
# 16  b'\x86\xa1v\x04\xa2ts\xd9 2025-07-22T11:09:38....
# 17  b'\x86\xa1v\x04\xa2ts\xd9 2025-07-22T11:09:38....
# 18  b'\x86\xa1v\x04\xa2ts\xd9 2025-07-22T11:09:38....
# 19  b'\x86\xa1v\x04\xa2ts\xd9 2025-07-22T11:09:40....
# 20  b'\x86\xa1v\x04\xa2ts\xd9 2025-07-22T11:09:40....
# 21  b'\x86\xa1v\x04\xa2ts\xd9 2025-07-22T11:09:40....
# 22  b'\x86\xa1v\x04\xa2ts\xd9 2025-07-22T11:09:42....
# 23  b'\x86\xa1v\x04\xa2ts\xd9 2025-07-22T11:09:42....
# 24  b'\x86\xa1v\x04\xa2ts\xd9 2025-07-22T11:09:42....
# 25  b'\x86\xa1v\x04\xa2ts\xd9 2025-07-22T11:09:45....
# 26  b'\x86\xa1v\x04\xa2ts\xd9 2025-07-22T11:12:42....
# 27  b'\x86\xa1v\x04\xa2ts\xd9 2025-07-22T11:12:42....
# 28  b'\x86\xa1v\x04\xa2ts\xd9 2025-07-22T11:12:43....
# 29  b'\x86\xa1v\x04\xa2ts\xd9 2025-07-22T11:12:49....
# 30  b'\x86\xa1v\x04\xa2ts\xd9 2025-07-22T11:12:51....
# 31  b'\x86\xa1v\x04\xa2ts\xd9 2025-07-22T11:12:51....
# 32  b'\x86\xa1v\x04\xa2ts\xd9 2025-07-22T11:12:51....
# 33  b'\x86\xa1v\x04\xa2ts\xd9 2025-07-22T11:12:52....
# 34  b'\x86\xa1v\x04\xa2ts\xd9 2025-07-22T11:12:57....
# 35  b'\x86\xa1v\x04\xa2ts\xd9 2025-07-22T11:12:58....
# 36  b'\x86\xa1v\x04\xa2ts\xd9 2025-07-22T11:12:58....
# 37  b'\x86\xa1v\x04\xa2ts\xd9 2025-07-22T11:12:58....
# 38  b'\x86\xa1v\x04\xa2ts\xd9 2025-07-22T11:13:01....
# 39  b'\x86\xa1v\x04\xa2ts\xd9 2025-07-22T11:13:01....
# 40  b'\x86\xa1v\x04\xa2ts\xd9 2025-07-22T11:13:01....
# 41  b'\x86\xa1v\x04\xa2ts\xd9 2025-07-22T11:13:03....
# 42  b'\x86\xa1v\x04\xa2ts\xd9 2025-07-22T11:13:03....
# 43  b'\x86\xa1v\x04\xa2ts\xd9 2025-07-22T11:13:03....
# 44  b'\x86\xa1v\x04\xa2ts\xd9 2025-07-22T11:13:04....
# 45  b'\x86\xa1v\x04\xa2ts\xd9 2025-07-22T11:13:04....
# 46  b'\x86\xa1v\x04\xa2ts\xd9 2025-07-22T11:13:04....
# 47  b'\x86\xa1v\x04\xa2ts\xd9 2025-07-22T11:13:08....
#
#                                              metadata
# 0   b'{"source": "input", "step": -1, "parents": {}}'
# 1     b'{"source": "loop", "step": 0, "parents": {}}'
# 2     b'{"source": "loop", "step": 1, "parents": {}}'
# 3     b'{"source": "loop", "step": 2, "parents": {}}'
# 4     b'{"source": "loop", "step": 3, "parents": {}}'
# 5     b'{"source": "loop", "step": 4, "parents": {}}'
# 6     b'{"source": "loop", "step": 5, "parents": {}}'
# 7    b'{"source": "input", "step": 6, "parents": {}}'
# 8     b'{"source": "loop", "step": 7, "parents": {}}'
# 9     b'{"source": "loop", "step": 8, "parents": {}}'
# 10    b'{"source": "loop", "step": 9, "parents": {}}'
# 11   b'{"source": "loop", "step": 10, "parents": {}}'
# 12   b'{"source": "loop", "step": 11, "parents": {}}'
# 13   b'{"source": "loop", "step": 12, "parents": {}}'
# 14  b'{"source": "input", "step": 13, "parents": {}}'
# 15   b'{"source": "loop", "step": 14, "parents": {}}'
# 16   b'{"source": "loop", "step": 15, "parents": {}}'
# 17  b'{"source": "input", "step": -1, "parents": {}}'
# 18    b'{"source": "loop", "step": 0, "parents": {}}'
# 19    b'{"source": "loop", "step": 1, "parents": {}}'
# 20  b'{"source": "input", "step": 16, "parents": {}}'
# 21   b'{"source": "loop", "step": 17, "parents": {}}'
# 22   b'{"source": "loop", "step": 18, "parents": {}}'
# 23  b'{"source": "input", "step": 19, "parents": {}}'
# 24   b'{"source": "loop", "step": 20, "parents": {}}'
# 25   b'{"source": "loop", "step": 21, "parents": {}}'
# 26  b'{"source": "input", "step": 22, "parents": {}}'
# 27   b'{"source": "loop", "step": 23, "parents": {}}'
# 28   b'{"source": "loop", "step": 24, "parents": {}}'
# 29   b'{"source": "loop", "step": 25, "parents": {}}'
# 30   b'{"source": "loop", "step": 26, "parents": {}}'
# 31  b'{"source": "input", "step": 27, "parents": {}}'
# 32   b'{"source": "loop", "step": 28, "parents": {}}'
# 33   b'{"source": "loop", "step": 29, "parents": {}}'
# 34   b'{"source": "loop", "step": 30, "parents": {}}'
# 35   b'{"source": "loop", "step": 31, "parents": {}}'
# 36  b'{"source": "input", "step": 32, "parents": {}}'
# 37   b'{"source": "loop", "step": 33, "parents": {}}'
# 38   b'{"source": "loop", "step": 34, "parents": {}}'
# 39   b'{"source": "input", "step": 2, "parents": {}}'
# 40    b'{"source": "loop", "step": 3, "parents": {}}'
# 41    b'{"source": "loop", "step": 4, "parents": {}}'
# 42  b'{"source": "input", "step": 35, "parents": {}}'
# 43   b'{"source": "loop", "step": 36, "parents": {}}'
# 44   b'{"source": "loop", "step": 37, "parents": {}}'
# 45  b'{"source": "input", "step": 38, "parents": {}}'
# 46   b'{"source": "loop", "step": 39, "parents": {}}'
# 47   b'{"source": "loop", "step": 40, "parents": {}}'
#    thread_id checkpoint_ns                         checkpoint_id  \
# 0          1                1f066ec4-49c7-6046-bfff-aa65c5cbcec3
# 1          1                1f066ec4-49c7-6046-bfff-aa65c5cbcec3
# 2          1                1f066ec4-49c8-66a8-8000-4b08d16125ef
# 3          1                1f066ec4-49c8-66a8-8000-4b08d16125ef
# 4          1                1f066ec4-6070-60b8-8001-00e909555671
# 5          1                1f066ec4-6070-60b8-8001-00e909555671
# 6          1                1f066ec4-97be-65c4-8002-8daa640e6861
# 7          1                1f066ec4-97be-65c4-8002-8daa640e6861
# 8          1                1f066ec4-a2af-6910-8003-1170cfbe1fe8
# 9          1                1f066ec4-a2af-6910-8003-1170cfbe1fe8
# 10         1                1f066ec4-deff-6b18-8004-ef6df0779f6a
# 11         1                1f066ec4-fd55-69a0-8006-d0009df1319f
# 12         1                1f066ec4-fd55-69a0-8006-d0009df1319f
# 13         1                1f066ec4-fd57-6480-8007-227b38662929
# 14         1                1f066ec4-fd57-6480-8007-227b38662929
# 15         1                1f066ec5-09cc-6760-8008-07515c154ab5
# 16         1                1f066ec5-09cc-6760-8008-07515c154ab5
# 17         1                1f066ec5-3cc4-6992-8009-b85b83aa92b4
# 18         1                1f066ec5-3cc4-6992-8009-b85b83aa92b4
# 19         1                1f066ec5-57f9-6488-800a-0f456c16e0ac
# 20         1                1f066ec5-57f9-6488-800a-0f456c16e0ac
# 21         1                1f066ec5-8fc5-6c2c-800b-6395c5880df3
# 22         1                1f066ec5-a2c3-666c-800d-c074f571f05c
# 23         1                1f066ec5-a2c3-666c-800d-c074f571f05c
# 24         1                1f066ec5-a2c5-6a70-800e-5b390d5b2976
# 25         2                1f066ec5-b7e4-624e-bfff-70a3fe8edeee
# 26         2                1f066ec5-b7e4-624e-bfff-70a3fe8edeee
# 27         2                1f066ec5-b7e5-6b6c-8000-ef3be16b59fc
# 28         1                1f066ec5-d217-6af8-8010-d8f6ab20010a
# 29         1                1f066ec5-d217-6af8-8010-d8f6ab20010a
# 30         1                1f066ec5-d21a-608c-8011-77f72934f83e
# 31         1                1f066ec5-e1ba-60fa-8013-cc7acbad5ded
# 32         1                1f066ec5-e1ba-60fa-8013-cc7acbad5ded
# 33         1                1f066ec5-e1bc-6e22-8014-1da7d3d1b498
# 34         1                1f066ecc-9771-6be0-8016-9bff5c6030c6
# 35         1                1f066ecc-9771-6be0-8016-9bff5c6030c6
# 36         1                1f066ecc-9826-65ea-8017-d9eba0120f19
# 37         1                1f066ecc-9826-65ea-8017-d9eba0120f19
# 38         1                1f066ecc-a34d-68e2-8018-008853db5a9e
# 39         1                1f066ecc-a34d-68e2-8018-008853db5a9e
# 40         1                1f066ecc-d713-69c4-8019-acefed21b048
# 41         1                1f066ecc-e7b1-6e84-801b-c1b8d5c47352
# 42         1                1f066ecc-e7b1-6e84-801b-c1b8d5c47352
# 43         1                1f066ecc-e7b4-6d46-801c-460e75eda38a
# 44         1                1f066ecc-e7b4-6d46-801c-460e75eda38a
# 45         1                1f066ecc-f3cd-6dbc-801d-16d70be516fd
# 46         1                1f066ecc-f3cd-6dbc-801d-16d70be516fd
# 47         1                1f066ecd-2341-6d6e-801e-1ae39eee4921
# 48         1                1f066ecd-2f08-6256-8020-98c20b22a666
# 49         1                1f066ecd-2f08-6256-8020-98c20b22a666
# 50         1                1f066ecd-2f0b-62d0-8021-d19842093626
# 51         2                1f066ecd-4871-6ce2-8002-0eb227fdf6b0
# 52         2                1f066ecd-4871-6ce2-8002-0eb227fdf6b0
# 53         2                1f066ecd-4874-6014-8003-4c7adb383f9a
# 54         1                1f066ecd-5a21-64a6-8023-9f708beb1d3b
# 55         1                1f066ecd-5a21-64a6-8023-9f708beb1d3b
# 56         1                1f066ecd-5a24-63b8-8024-7a9777ddb6e0
# 57         1                1f066ecd-69b4-60e4-8026-780ddfd1e793
# 58         1                1f066ecd-69b4-60e4-8026-780ddfd1e793
# 59         1                1f066ecd-69b6-63b2-8027-09df719c6a4f
#
#                                  task_id  idx           channel     type  \
# 0   32a14325-9c75-400b-9283-1f51a401f863    0          messages  msgpack
# 1   32a14325-9c75-400b-9283-1f51a401f863    1     branch:to:llm     null
# 2   74937027-0a4e-d734-2697-0daf5bbe46de    0          messages  msgpack
# 3   74937027-0a4e-d734-2697-0daf5bbe46de    1  branch:to:action     null
# 4   204008f9-5db7-21cf-b262-300d3a722e9d    0          messages  msgpack
# 5   204008f9-5db7-21cf-b262-300d3a722e9d    1     branch:to:llm     null
# 6   76e53e09-b1e4-1230-7924-e1743e7fbd87    0          messages  msgpack
# 7   76e53e09-b1e4-1230-7924-e1743e7fbd87    1  branch:to:action     null
# 8   c79ddf42-7512-b309-c134-100060b4fc00    0          messages  msgpack
# 9   c79ddf42-7512-b309-c134-100060b4fc00    1     branch:to:llm     null
# 10  11e14545-8296-ced5-abc6-e95b1246e46c    0          messages  msgpack
# 11  ff075cfa-75c3-9c56-2761-9604b540b3ec    0          messages  msgpack
# 12  ff075cfa-75c3-9c56-2761-9604b540b3ec    1     branch:to:llm     null
# 13  716d778b-6f8e-ff32-b82e-5cc763f24978    0          messages  msgpack
# 14  716d778b-6f8e-ff32-b82e-5cc763f24978    1  branch:to:action     null
# 15  991db18d-1843-9857-b102-0a4db9fa18a3    0          messages  msgpack
# 16  991db18d-1843-9857-b102-0a4db9fa18a3    1     branch:to:llm     null
# 17  8daa3c36-4856-5f71-5c06-ab6d6729c509    0          messages  msgpack
# 18  8daa3c36-4856-5f71-5c06-ab6d6729c509    1  branch:to:action     null
# 19  528451ea-1d22-2207-d7e7-303d12ea6ab6    0          messages  msgpack
# 20  528451ea-1d22-2207-d7e7-303d12ea6ab6    1     branch:to:llm     null
# 21  3a2ee3e2-2dbd-94f8-72da-39b850a27587    0          messages  msgpack
# 22  facaf2ba-5795-c4c0-a9bd-86179744de85    0          messages  msgpack
# 23  facaf2ba-5795-c4c0-a9bd-86179744de85    1     branch:to:llm     null
# 24  262ba0f1-e335-5680-c680-713335564420    0          messages  msgpack
# 25  598f5da5-6ecc-e3c0-9725-f574c6e33a0d    0          messages  msgpack
# 26  598f5da5-6ecc-e3c0-9725-f574c6e33a0d    1     branch:to:llm     null
# 27  58788803-4e53-eec7-28c7-680012708336    0          messages  msgpack
# 28  441e803c-4a12-290a-a473-b7698d724cc6    0          messages  msgpack
# 29  441e803c-4a12-290a-a473-b7698d724cc6    1     branch:to:llm     null
# 30  5c982902-579a-9cff-70d1-058d72ff7846    0          messages  msgpack
# 31  748a356d-54df-1732-6f8c-e762301f2e89    0          messages  msgpack
# 32  748a356d-54df-1732-6f8c-e762301f2e89    1     branch:to:llm     null
# 33  125719d4-018b-4cf0-92b6-e1a7ba826d7b    0          messages  msgpack
# 34  337d6004-db33-4962-8fc8-9a496df52a6b    0          messages  msgpack
# 35  337d6004-db33-4962-8fc8-9a496df52a6b    1     branch:to:llm     null
# 36  95609ced-61a8-0853-8aca-5607f7366a5b    0          messages  msgpack
# 37  95609ced-61a8-0853-8aca-5607f7366a5b    1  branch:to:action     null
# 38  98874abb-727c-b6e4-1cc5-c41d1c138223    0          messages  msgpack
# 39  98874abb-727c-b6e4-1cc5-c41d1c138223    1     branch:to:llm     null
# 40  b429d1af-0112-ade3-4d52-a52969bc985a    0          messages  msgpack
# 41  6f6897a6-117b-0c5f-0ae2-459e6b6a4805    0          messages  msgpack
# 42  6f6897a6-117b-0c5f-0ae2-459e6b6a4805    1     branch:to:llm     null
# 43  fc2c0ad4-d130-e607-08f7-b996b87c2241    0          messages  msgpack
# 44  fc2c0ad4-d130-e607-08f7-b996b87c2241    1  branch:to:action     null
# 45  f54ba748-1584-3a5d-91b7-3c00dbeb1184    0          messages  msgpack
# 46  f54ba748-1584-3a5d-91b7-3c00dbeb1184    1     branch:to:llm     null
# 47  671dadc0-a69e-614b-413a-d75fcd9737e0    0          messages  msgpack
# 48  a0ef2173-0b48-c4c5-144d-7b4c890aba39    0          messages  msgpack
# 49  a0ef2173-0b48-c4c5-144d-7b4c890aba39    1     branch:to:llm     null
# 50  39133473-58f3-b733-e6d2-0472fba7c080    0          messages  msgpack
# 51  dcaacbe5-3dc9-f0f0-da9c-397b0bcd548b    0          messages  msgpack
# 52  dcaacbe5-3dc9-f0f0-da9c-397b0bcd548b    1     branch:to:llm     null
# 53  5554d42a-e2d5-c7c7-fb95-75701fdde125    0          messages  msgpack
# 54  9a4395a3-123f-0829-4653-513d28eaf75f    0          messages  msgpack
# 55  9a4395a3-123f-0829-4653-513d28eaf75f    1     branch:to:llm     null
# 56  40ae604d-9413-cd4e-8334-91f9ee0e2fe6    0          messages  msgpack
# 57  d7ee3e75-183e-cfd6-9cb1-65d2eb2d7760    0          messages  msgpack
# 58  d7ee3e75-183e-cfd6-9cb1-65d2eb2d7760    1     branch:to:llm     null
# 59  3651c0d4-cd3e-cbd2-46b8-55ab403f4b09    0          messages  msgpack
#
#                                                 value
# 0   b'\x91\xc7\xac\x05\x94\xbdlangchain_core.messa...
# 1                                                 b''
# 2   b'\x91\xc8\x03\xf4\x05\x94\xbalangchain_core.m...
# 3                                                 b''
# 4   b"\x91\xc8\x0c9\x05\x94\xbclangchain_core.mess...
# 5                                                 b''
# 6   b'\x91\xc8\x03\xf2\x05\x94\xbalangchain_core.m...
# 7                                                 b''
# 8   b"\x91\xc8\x0c\x1c\x05\x94\xbclangchain_core.m...
# 9                                                 b''
# 10  b"\x91\xc8\x04\xc2\x05\x94\xbalangchain_core.m...
# 11  b'\x91\xc7\xa5\x05\x94\xbdlangchain_core.messa...
# 12                                                b''
# 13  b'\x91\xc8\x04\x02\x05\x94\xbalangchain_core.m...
# 14                                                b''
# 15  b'\x91\xc8\x0cz\x05\x94\xbclangchain_core.mess...
# 16                                                b''
# 17  b'\x91\xc8\x03\xfc\x05\x94\xbalangchain_core.m...
# 18                                                b''
# 19  b'\x91\xc8\x0cz\x05\x94\xbclangchain_core.mess...
# 20                                                b''
# 21  b"\x91\xc8\x04\xbf\x05\x94\xbalangchain_core.m...
# 22  b'\x91\xc7\xa2\x05\x94\xbdlangchain_core.messa...
# 23                                                b''
# 24  b'\x91\xc8\x04a\x05\x94\xbalangchain_core.mess...
# 25  b'\x91\xc7\xa2\x05\x94\xbdlangchain_core.messa...
# 26                                                b''
# 27  b'\x91\xc8\x03\x86\x05\x94\xbalangchain_core.m...
# 28  b'\x91\xc7\xa2\x05\x94\xbdlangchain_core.messa...
# 29                                                b''
# 30  b'\x91\xc8\x04\x86\x05\x94\xbalangchain_core.m...
# 31  b'\x91\xc7\xa2\x05\x94\xbdlangchain_core.messa...
# 32                                                b''
# 33  b'\x91\xc8\x05\x84\x05\x94\xbalangchain_core.m...
# 34  b'\x91\xc7\xac\x05\x94\xbdlangchain_core.messa...
# 35                                                b''
# 36  b'\x91\xc8\x04\x04\x05\x94\xbalangchain_core.m...
# 37                                                b''
# 38  b"\x91\xc8\x07\xeb\x05\x94\xbclangchain_core.m...
# 39                                                b''
# 40  b'\x91\xc8\x04,\x05\x94\xbalangchain_core.mess...
# 41  b'\x91\xc7\xa5\x05\x94\xbdlangchain_core.messa...
# 42                                                b''
# 43  b'\x91\xc8\x04\x0b\x05\x94\xbalangchain_core.m...
# 44                                                b''
# 45  b"\x91\xc8\x06\xf5\x05\x94\xbclangchain_core.m...
# 46                                                b''
# 47  b'\x91\xc8\x03\xd9\x05\x94\xbalangchain_core.m...
# 48  b'\x91\xc7\xa2\x05\x94\xbdlangchain_core.messa...
# 49                                                b''
# 50  b'\x91\xc8\x04\xbb\x05\x94\xbalangchain_core.m...
# 51  b'\x91\xc7\xa2\x05\x94\xbdlangchain_core.messa...
# 52                                                b''
# 53  b'\x91\xc8\x03\x82\x05\x94\xbalangchain_core.m...
# 54  b'\x91\xc7\xa2\x05\x94\xbdlangchain_core.messa...
# 55                                                b''
# 56  b'\x91\xc8\x04V\x05\x94\xbalangchain_core.mess...
# 57  b'\x91\xc7\xa2\x05\x94\xbdlangchain_core.messa...
# 58                                                b''
# 59  b"\x91\xc8\x05\xb5\x05\x94\xbalangchain_core.m...

# %% [markdown]
# ## Streaming tokens

# %%
# pip install aiosqlite
from langgraph.checkpoint.sqlite.aio import AsyncSqliteSaver

memory = AsyncSqliteSaver.from_conn_string(":memory:")
abot = Agent(model, [tool], system=prompt, checkpointer=memory)

# %%
messages = [HumanMessage(content="What is the weather in SF?")]
thread = {"configurable": {"thread_id": "4"}}

async def run_stream():
    async with AsyncSqliteSaver.from_conn_string(":memory:") as memory:  # ✅ 注意这里是 async with
        abot = Agent(model, [tool], system=prompt, checkpointer=memory)

        async for event in abot.graph.astream_events({"messages": messages}, thread, version="v1"):
            kind = event["event"]
            if kind == "on_chat_model_stream":
                content = event["data"]["chunk"].content
                if content:
                    print(content, end="|")

await run_stream()
# Out:
# /Users/isdance/Desktop/ai_projects/agent_in_langgraph/.venv/lib/python3.12/site-packages/pydantic/_internal/_known_annotated_metadata.py:106: RuntimeWarning: coroutine 'run_stream' was never awaited
#   def expand_grouped_metadata(annotations: Iterable[Any]) -> Iterable[Any]:
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# Calling: {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in San Francisco'}, 'id': 'call_w7CLUrHdBKvW6jpLaVU4Krx9', 'type': 'tool_call'}
# Back to the model!
# The| current| weather| in| San| Francisco| is| mainly| cloudy|,| with| a| high| of| around| |64|°F| (|approximately| |18|°C|)| during| the| day|.| The| temperatures| are| expected| to| drop| to| a| low| of| about| |56|°F| (|approximately| |13|°C|)| at| night|.| Winds| are| coming| from| the| west| at| |10| to| |20| mph|.
#
# |For| more| details|,| you| can| check| the| comprehensive| weather| report| [|here|](|https|://|weather|.com|/weather|/t|oday|/l|/S|an|+|Franc|isco|+|CA|+|US|CA|098|7|:|1|:|US|).|
